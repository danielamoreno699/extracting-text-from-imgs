# %%
import pytesseract as tess
import numpy as np

# %%
from PIL import Image
from IPython.display import Image, display
import cv2
from matplotlib import pyplot as plt

# %%
from PIL import Image

# %%
imagedata_original = cv2.imread(r'C:\Users\USUARIO\OneDrive\Escritorio\xx.jpg', 0)

# %%
ret, threshold_1 = cv2.threshold(imagedata_original, 127, 255, cv2.THRESH_BINARY)

# %%
title = ['binary']
image22 = [threshold_1]

# %%
plt.imshow(threshold_1, cmap='gray')
plt.show()

# %%
image_modified = tess.image_to_string(threshold_1,lang= "spa")

# %%
print(image_modified)
# Out:
#
#
#
#
#
#
# COLORS trers
#
# PROMOCIÓN
# CABELLO SANO
#
# Durante el mes
# de Enera y tebrero
#
# TINTE + PETNADO
# 24 EUROS
#
# Disfruta de la pramoción durante tada la semana
# ghd — KÉRASTASE vomn

# %%
image = Image.open(r'C:\Users\USUARIO\OneDrive\Escritorio\xx.jpg')

# %%
print(image.format)
print(image.mode)
print(image.size)
# Out:
# JPEG
# RGB
# (500, 400)

# %%
gs_image = image.convert(mode='L')

# %%
gs_image.show()

# %%
gs2 = tess.image_to_string(gs_image,lang= "spa")

# %%
print(gs2)
# Out:
#
#
#
# COLORS rís.ens
#
# PROMOCIÓN
# CABELLO SANO
#
# Durante el mes
# de Enero. y Febrero
#
#
#
#
#
#
#
#
#
# 24 EUROS
#
#
#
# Disfruta de la promoción durante toda la semana
# ohd — KÉRASTASE -voren

# %%
img_resized = gs_image.resize((300,300))

# %%
print(img_resized)
# Out:
# <PIL.Image.Image image mode=L size=300x300 at 0x227A3C2B888>

# %%
gs3 = tess.image_to_string(img_resized,lang= "spa")

# %%
print(gs3)
# Out:
# COLORS
#
# PROMOCIÓN
# CABELLO SANO — Y
#
# Durante el mes
# de Eneo y Febicro
#
# TINTE + PEIVADO
# 24 EUROS
#
#
#
# Disfiuto de lo pomsción durante tado la semana
# qhd - KÉRASTASE -voma.

# %%
imagedata_original = cv2.imread(r'C:\Users\USUARIO\OneDrive\Escritorio\peluqueria.jpg', 0)

# %%
image = Image.open(r'C:\Users\USUARIO\OneDrive\Escritorio\peluqueria.jpg')

# %%
gs_image2 = image.convert(mode='L')

# %%
print(image.format)
print(image.mode)
print(image.size)
# Out:
# JPEG
# RGB
# (512, 512)

# %%
gs223 = tess.image_to_string(image,lang= "spa")

# %%
print(gs223)
# Out:
#
#
# u
#
# E
#
# Jatgas
# alon
#
# "Revoluciona u belleza"
#
# Tratamiento de Keratina
# a tan sólo $40
#
# Incluye:
# * Corte
# * Retiro de Keratina
# * Planchado
#
# 'Gratis depilación de cejas
#
# llo corto consultar precio especial del mes
# lido para pago en efectivo o transferencia

# %%
import tensorflow
